# %%
from tkinter import *
import tkinter as tk
from tkinter import ttk, messagebox
import re


regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
user_dict={}

# %%
def password_check(passwd): 
      
    SpecialSym =['$', '@', '#', '%'] 
    val = True      
    if len(passwd) < 6: 
        print('length should be at least 6') 
        val = False          
    if len(passwd) > 20: 
        print('length should be not be greater than 8') 
        val = False          
    if not any(char.isdigit() for char in passwd): 
        print('Password should have at least one numeral') 
        val = False          
    if not any(char.isupper() for char in passwd): 
        print('Password should have at least one uppercase letter') 
        val = False          
    if not any(char.islower() for char in passwd): 
        print('Password should have at least one lowercase letter') 
        val = False          
    if not any(char in SpecialSym for char in passwd): 
        print('Password should have at least one of the symbols $@#') 
        val = False
    if val: 
        return val

# %%
def member():
    winmember=Tk()
    winmember.title("Membership Benefits")
    winmember.maxsize(width=500 ,  height=340)
    winmember.minsize(width=500 ,  height=340)
    
    heading = Label(winmember , text = "Membership Benefits : " , font = 'Verdana 15 bold')
    heading.place(x=45, y=40)
    
    heading = Label(winmember , text = "\u2022  Free delivery" , font = 'Verdana 10 bold')
    heading.place(x=45, y=80)
    
    heading = Label(winmember , text = "\u2022  10% off on each order" , font = 'Verdana 10 bold')
    heading.place(x=45, y=100)
    
    heading = Label(winmember , text = "\u2022  50% off on 1st order up to 1000(currency)" , font = 'Verdana 10 bold')
    heading.place(x=45, y=120)
    
    heading = Label(winmember , text = "Do you want to be a prime member ?" , font = 'Verdana 12 bold')
    heading.place(x=45, y=220)
    
    yes = Button(winmember , text="YES",width=22)
    yes.place(x=45 , y =250)
    
    no = Button(winmember , text="NO",width=21)
    no.place(x=211 , y =250)
    
    
    winmember.mainloop()

# %%
def signup():
    
    def check_already():
        
        print(gender.get())
        
        logic='''1. Should have at least one number.\n2. Should have at least one uppercase and one lowercase character.\n3. Should have at least one special symbol.\n4. Should be between 6 to 20 characters long.'''
        if(not name.get() or not email.get() or not email.get() or not age.get() or not address.get() or not gender.get()):
            print(gender.get())
            messagebox.showerror("Error", "Enter all Credentials") 
        else:
            pass
        
        if(re.search(regex,email.get())):
            if(password.get()==very_pass.get()):
                if(password_check(password.get())):
                    user_dict['name']=name.get()
                    user_dict['email']=email.get()
                    user_dict['age']=age.get()
                    user_dict['country']=country.get()
                    user_dict['gender']=gender.get()
                    user_dict['address']=address.get()

                    if False : #check if alredy user exists afer register
                        pass
                    else:
                        member()
                else:
                     messagebox.showerror("Error", "Enter Valid password. The password should contain : \n"+logic) 
            else:
                messagebox.showerror("Error", "Password didnot match") 
        else:
            messagebox.showerror("Error", "Enter valid Email ") 

    #win.destroy()

    # start Signup Windowm

    winsignup = Tk()
    winsignup.title("Sign Up")
    winsignup.maxsize(width=500 ,  height=500)
    winsignup.minsize(width=500 ,  height=500)


    #heading label
    heading = Label(winsignup , text = "Signup" , font = 'Verdana 20 bold')
    heading.place(x=50 , y=60-10)

    # form data label
    name = Label(winsignup, text= "Name :" , font='Verdana 10 bold')
    name.place(x=50,y=130-10)

    email = Label(winsignup, text= "Email :" , font='Verdana 10 bold')
    email.place(x=50,y=160-10)

    age = Label(winsignup, text= "Age :" , font='Verdana 10 bold')
    age.place(x=50,y=190-10)

    Gender = Label(winsignup, text= "Gender :" , font='Verdana 10 bold')
    Gender.place(x=50,y=220-10)

    country = Label(winsignup, text= "Country :" , font='Verdana 10 bold')
    country.place(x=50,y=260-10)

    add = Label(winsignup, text= "Address :" , font='Verdana 10 bold')
    add.place(x=50,y=290-10)


    password = Label(winsignup, text= "Password :" , font='Verdana 10 bold')
    password.place(x=50,y=320-10)

    very_pass = Label(winsignup, text= "Verify Password:" , font='Verdana 10 bold')
    very_pass.place(x=50,y=350-10)

    # Entry Box ------------------------------------------------------------------

    name = StringVar()
    email = StringVar()
    age = IntVar(winsignup, value='0')
    county= StringVar()
    gender=StringVar()
    address = StringVar()
    password = StringVar()
    very_pass = StringVar()


    name = Entry(winsignup, width=40 )
    name.place(x=200 , y=133-10)



    email = Entry(winsignup, width=40)
    email.place(x=200 , y=163-10)


    age = Entry(winsignup, width=40,)
    age.place(x=200 , y=193-10)


    Radio_button_male = ttk.Radiobutton(winsignup,text='Male', value="Male", variable=gender).place(x= 200 , y= 220-10)
    Radio_button_female = ttk.Radiobutton(winsignup,text='Female', value="Female",variable=gender).place(x= 200 , y= 238-10)


    country = ttk.Combobox(winsignup, width = 37)
    country.place(x=200 , y=263-10)
    country['values'] = (' India',  
                          ' United States',                         
                          ' Europe', 
                          ' Japan') 

    country.current(0) 

    address = Entry(winsignup, width=40)
    address.place(x=200 , y=293-10)

    password = Entry(winsignup, width=40,show="*")
    password.place(x=200 , y=353-10)


    very_pass= Entry(winsignup, width=40 ,show="*")
    very_pass.place(x=200 , y=323-10)
       

    # button login and clear

    btn_signup = Button(winsignup, text = "Signup" ,font='Verdana 10 bold', width=19, command=check_already)
    btn_signup.place(x=200, y=383-10)


    btn_login = Button(winsignup, text = "Clear" ,font='Verdana 10 bold')
    btn_login.place(x=392, y=383-10)


    sign_up_btn = Button(winsignup , text="Switch To Login" )
    sign_up_btn.place(x=350 , y =20-10)


    winsignup.mainloop()
signup()
# Out:
# Male
# length should be at least 6
# Password should have at least one numeral
# Password should have at least one uppercase letter
# Password should have at least one of the symbols $@#

# %%
def clear():
    userentry.delete(0,END)
    passentry.delete(0,END)
def login():
    print('login')
    







# !!!!! main !!!!!
win = Tk()

# app title
win.title("Billing App")

# window size
win.maxsize(width=500 ,  height=500)
win.minsize(width=500 ,  height=500)


#heading label
heading = Label(win , text = "Login" , font = 'Verdana 25 bold')
heading.place(x=80-20 , y=130-70)

email = Label(win, text= "Email :" , font='Verdana 10 bold')
email.place(x=80-20,y=200-70)

userpass = Label(win, text= "Password :" , font='Verdana 10 bold')
userpass.place(x=80-20,y=240-70)

# Entry Box
emial = StringVar()
password = StringVar()

email = Entry(win, width=40 , textvariable = email)
email.focus()
email.place(x=200-20, y=203-70)

passentry = Entry(win, width=40, show="*" ,textvariable = password)
passentry.place(x=200-20, y=240-70)


# button login and clear

btn_login = Button(win, text = "Login" ,font='Verdana 10 bold', width =19,command=login)
btn_login.place(x=200-20, y=273-70)

btn_clear = Button(win, text = "Clear" ,font='Verdana 10 bold', command= clear)
btn_clear.place(x=372, y=273-70)

# signup button

username = Label(win, text= "New user ? " , font='Verdana 10 bold')
username.place(x=80-20,y=260)

# register user
register_btn = Button(win , text="Register here....", width=12, command=signup)
register_btn.place(x=200-20, y =260)


win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-61-21a561689c99>", line 97, in signup
#     btn_signup = Button(winsignup, text = "Signup" ,font='Verdana 10 bold', width=19, command=member('con'))
# TypeError: member() takes 0 positional arguments but 1 was given
