# %%
from tkinter import *
import tkinter as tk
from tkinter import ttk, messagebox
import re


regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
user_dict={}

# %%
def password_check(passwd): 
      
    SpecialSym =['$', '@', '#', '%'] 
    val = True      
    if len(passwd) < 6: 
        print('length should be at least 6') 
        val = False          
    if len(passwd) > 20: 
        print('length should be not be greater than 8') 
        val = False          
    if not any(char.isdigit() for char in passwd): 
        print('Password should have at least one numeral') 
        val = False          
    if not any(char.isupper() for char in passwd): 
        print('Password should have at least one uppercase letter') 
        val = False          
    if not any(char.islower() for char in passwd): 
        print('Password should have at least one lowercase letter') 
        val = False          
    if not any(char in SpecialSym for char in passwd): 
        print('Password should have at least one of the symbols $@#') 
        val = False
    if val: 
        return val

# %%
def member():
    winmember=Tk()
    winmember.title("Membership Benefits")
    winmember.config(bg='light blue')
    winmember.maxsize(width=500 ,  height=400)
    winmember.minsize(width=500 ,  height=400)
    
    top_frame = Frame(winmember,bg='#000099',width=500, height=100)
    top_frame.place(x=0,y=0)
    
    heading = Label(winmember , text = "Membership Benefits : " , font = 'Verdana 23 bold',fg='white',bg='#000099')
    heading.place(x=45, y=25)
    
    heading = Label(winmember , text = "\u2022  Free delivery" , font = 'Verdana 12 bold',bg='light blue')
    heading.place(x=45, y=120)
    
    heading = Label(winmember , text = "\u2022  10% off on each order" , font = 'Verdana 12 bold',bg='light blue')
    heading.place(x=45, y=140)
    
    heading = Label(winmember , text = "\u2022  50% off on 1st order up to 1000(currency)" , font = 'Verdana 12 bold',bg='light blue')
    heading.place(x=45, y=160)
    
    heading = Label(winmember , text = "Do you want to be a prime member ?" , font = 'Verdana 13 bold',bg='light blue')
    heading.place(x=45, y=300)
    
    yes = Button(winmember , text="YES",width=23,bg='gold')
    yes.place(x=45 , y =340)
    
    no = Button(winmember , text="NO",width=23,bg='gold')
    no.place(x=225 , y =340)
    
    
    winmember.mainloop()

# %%
def signup():
    
    def clear():
        name.delete(0,END)
        email.delete(0,END)
        age.delete(0,END)
        country.delete(0,END)
        address.delete(0,END)    
        password.delete(0,END)
        very_pass.delete(0,END)
        
    
    def check_already():
        
        print(gender.get())
        
        logic='''1. Should have at least one number.\n2. Should have at least one uppercase and one lowercase character.\n3. Should have at least one special symbol.\n4. Should be between 6 to 20 characters long.'''
        
        if(name.get() and email.get() and email.get() and age.get() and address.get() and gender.get()):     
        
            if(re.search(regex,email.get())):
                
                if(password.get()==very_pass.get()):
                    
                    if(password_check(password.get())):
                        
                        user_dict['name']=name.get()
                        user_dict['email']=email.get()
                        user_dict['age']=age.get()
                        user_dict['country']=country.get()
                        user_dict['gender']=gender.get()
                        user_dict['address']=address.get()
                        user_dict['password']=password.get()

                        if False : #check if alredy user exists afer register
                            pass
                        else:
                            member()
                    else:
                         messagebox.showerror("Error", "Enter Valid password. The password should contain : \n"+logic) 
                else:
                    messagebox.showerror("Error", "Password didnot match") 
            else:
                messagebox.showerror("Error", "Enter valid Email ") 
        else:
            messagebox.showerror("Error", "Enter all Credentials") 


    #win.destroy()

    # start Signup Windowm

    winsignup = Tk()
    winsignup.title("Sign Up")
    winsignup.config(bg='light blue')
    winsignup.maxsize(width=500 ,  height=400)
    winsignup.minsize(width=500 ,  height=400)
    
    top_frame = Frame(winsignup,bg='#000099',width=500, height=85)
    top_frame.place(x=0,y=0)

    #heading label
    heading = Label(winsignup , text = "Signup" , font = 'Verdana 23 bold',fg='white',bg='#000099')
    heading.place(x=50 , y=20)

    # form data label
    name = Label(winsignup, text= "Name :" , font='Verdana 10 bold',bg='light blue')
    name.place(x=50,y=130-30)

    email = Label(winsignup, text= "Email :" , font='Verdana 10 bold',bg='light blue')
    email.place(x=50,y=160-30)

    age = Label(winsignup, text= "Age :" , font='Verdana 10 bold',bg='light blue')
    age.place(x=50,y=190-30)

    Gender = Label(winsignup, text= "Gender :" , font='Verdana 10 bold',bg='light blue')
    Gender.place(x=50,y=220-30)

    country = Label(winsignup, text= "Country :" , font='Verdana 10 bold',bg='light blue')
    country.place(x=50,y=260-30)

    add = Label(winsignup, text= "Address :" , font='Verdana 10 bold',bg='light blue')
    add.place(x=50,y=290-30)


    password = Label(winsignup, text= "Password :" , font='Verdana 10 bold',bg='light blue')
    password.place(x=50,y=320-30)

    very_pass = Label(winsignup, text= "Verify Password:" , font='Verdana 10 bold',bg='light blue')
    very_pass.place(x=50,y=350-30)

    # Entry Box ------------------------------------------------------------------

    name = StringVar()
    email = StringVar()
    age = IntVar(winsignup, value='0')
    county= StringVar()
    gender=StringVar()
    address = StringVar()
    password = StringVar()
    very_pass = StringVar()


    name = Entry(winsignup, width=40 )
    name.place(x=200 , y=133-30)



    email = Entry(winsignup, width=40)
    email.place(x=200 , y=163-30)


    age = Entry(winsignup, width=40,)
    age.place(x=200 , y=193-30)
    
    s = ttk.Style()                     # Creating style element
    s.configure('Wild.TRadiobutton',background='light blue')

    Radio_button_male = ttk.Radiobutton(winsignup,text='Male', value="Male", variable=gender,style='Wild.TRadiobutton')
    Radio_button_male.place(x= 200 , y= 220-30)
    
    Radio_button_female = ttk.Radiobutton(winsignup,text='Female', value="Female",variable=gender,style='Wild.TRadiobutton')
    Radio_button_female.place(x= 200 , y= 238-30)


    country = ttk.Combobox(winsignup, width = 37)
    country.place(x=200 , y=263-30)
    country['values'] = (' India',  
                          ' United States',                         
                          ' Europe', 
                          ' Japan') 

    country.current(0) 

    address = Entry(winsignup, width=40)
    address.place(x=200 , y=293-30)

    password = Entry(winsignup, width=40,show="*")
    password.place(x=200 , y=353-30)


    very_pass= Entry(winsignup, width=40 ,show="*")
    very_pass.place(x=200 , y=323-30)
       

    # button login and clear

    btn_signup = Button(winsignup, text = "Signup" ,font='Verdana 10 bold', width=19, command=check_already,bg='gold')
    btn_signup.place(x=200, y=383-30)


    btn_login = Button(winsignup, text = "Clear" ,font='Verdana 10 bold', command=clear,bg='gold')
    btn_login.place(x=392, y=383-30)


    winsignup.mainloop()

# %%
def clear():
    email.delete(0,END)
    passentry.delete(0,END)
def login():
    print('login')
def check_input():
    if(email.get()):
        if(re.search(regex,email.get())):
            if(passentry.get()):
                if(user_type.get()=='Admin'):
                    print('admin')
                elif(user_type.get()=='User'):
                    print('user')
            else:
                messagebox.showerror("Error", "Enter Password") 
        else
    else:
        messagebox.showerror("Error", "Enter Email") 
            
    

# !!!!! main !!!!!
win = Tk()

# app title
win.title("Billing App")
win.config(bg='light blue')
# window size
win.maxsize(width=500 ,  height=400)
win.minsize(width=500 ,  height=400)

top_frame = Frame(win,bg='#000099',width=500, height=100)
top_frame.place(x=0,y=0)
#heading label
heading = Label(top_frame , text = "Login" , font = 'Verdana 25 bold',bg='#000099',fg='white')
heading.place(x=60 , y=25)

email = Label(win, text= "Email :" , font='Verdana 10 bold',bg='light blue')
email.place(x=80-20,y=200-70)

userpass = Label(win, text= "Password :" , font='Verdana 10 bold',bg='light blue')
userpass.place(x=80-20,y=240-70)

# Entry Box
emial = StringVar()
password = StringVar()

email = Entry(win, width=40 , textvariable = email)
email.focus()
email.place(x=200-20, y=203-70)

passentry = Entry(win, width=40, show="*" ,textvariable = password)
passentry.place(x=200-20, y=240-70)


# button login and clear

'''btn_login = Button(win, text = "Login" ,font='Verdana 10 bold', width =19,command=login,bg='gold')
btn_login.place(x=200-20, y=273-70)

btn_clear = Button(win, text = "Clear" ,font='Verdana 10 bold', command=clear,bg='gold')
btn_clear.place(x=372, y=273-70)'''


s = ttk.Style()                     # Creating style element
s.configure('Wild.TRadiobutton',background='light blue')

userpass = Label(win, text= "Log in as ....." , font='Verdana 10 bold',bg='light blue')
userpass.place(x=60,y=210)

user_type=StringVar(None,"User")

Radio_button_user = ttk.Radiobutton(win,text='User', value="User",variable=user_type,style='Wild.TRadiobutton')
Radio_button_user.place(x= 180 , y= 210)

Radio_button_admin = ttk.Radiobutton(win,text='Admin', value="Admin",variable=user_type,style='Wild.TRadiobutton')
Radio_button_admin.place(x= 240 , y= 210)

btn_login = Button(win, text = "Login" ,font='Verdana 10 bold', width =19,command=check_input,bg='gold')
btn_login.place(x=200-20, y=273-25)

btn_clear = Button(win, text = "Clear" ,font='Verdana 10 bold', command=clear,bg='gold')
btn_clear.place(x=372, y=273-25)

# signup button

username = Label(win, text= "New user ? " , font='Verdana 10 bold',bg='light blue')
username.place(x=80-20,y=330)

# register user
register_btn = Button(win , text="Register here....", width=12, command=signup, bg='gold')
register_btn.place(x=200-20, y =330)


    

win.mainloop()
# Out:
# user
